# %% [markdown]
# # Plotting motif densities vs IUPred 1.0 long disorder fraction by category
#
# Aggregated Disopred scores and derived structural categories are used.
#
# Both Anchor and overall motif densities are plotted.

# %%
import json
import glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import sys
sys.path.append('../src/')

import aepathdisorder as aepd

# %matplotlib inline

# %%
ehec_anchor = aepd.load_single_table('../data/anchor/EHEC_effectors/EHEC_anchor.table')
ehec_disopred = aepd.load_single_table('../data/disopred/EHEC_effectors/EHEC_disopred-pb.table')
ehec_iupred_agg = aepd.load_multi_tables(path_to_folder='../data/iupred_aggregated_disfrac-class/EHEC_effectors/', regex='*long*.table')

# %%
fig=plt.figure(figsize=(4,4))

ax = fig.add_subplot(111)

sns.scatterplot(x=ehec_iupred_agg['disorder_fraction'], 
                y=ehec_anchor['anchor_motif_density'], 
                hue=ehec_iupred_agg['disorder_category'],
                palette = ['#1f77b4', '#6ba5cd', '#d62728', '#e47171'],
                ax=ax)

#handles, labels = ax.get_legend_handles_labels()
#ax.legend([handles[0], handles[2], handles[4], handles[3], handles[1]], ['Categories', 'IDP', 'PDR', 'NDP', 'ORD'])
plt.xlim(-0.01,1)
plt.ylim(-0.01,1)
plt.title('EHEC: Anchor motif density vs disorder fraction');

plt.savefig('../figures/EHEC_motif_density-vs-iupred-long_disfrac_by_category.png',
            dpi=300)

# %%
fig=plt.figure(figsize=(4,4))

ax = fig.add_subplot(111)

sns.scatterplot(x=ehec_iupred_agg['disorder_fraction'], 
                y=ehec_anchor['overall_motif_density'], 
                hue=ehec_iupred_agg['disorder_category'],
                palette = ['#1f77b4', '#6ba5cd', '#d62728', '#e47171'],
                ax=ax)

#handles, labels = ax.get_legend_handles_labels()
#ax.legend([handles[0], handles[2], handles[4], handles[3], handles[1]], ['Categories', 'IDP', 'PDR', 'NDP', 'ORD'])
plt.xlim(-0.01,1)
plt.ylim(-0.01,1)
plt.title('EHEC: Overall motif density vs disorder fraction');

plt.savefig('../figures/EHEC_overall_motif_density-vs-iupred-long_disfrac_by_category.png',
            dpi=300)

# %%
ehec_anchor[ehec_iupred_agg['disorder_category']=='PDR']
# Out:
#            dataset  anchor_ratio  anchor_motif_occ  anchor_motif_density  \
# protein_ac
# Q7DB50        EHEC      0.082915                 2              0.363636
# Q8XAJ5        EHEC      0.086168                 4              0.447368
# Q8XAL6        EHEC      0.122112                 2              0.324324
# Q8XC86        EHEC      0.051282                 2              0.562500
#
#             overall_motif_density  motif_occ_density
# protein_ac
# Q7DB50                   0.030151           0.005025
# Q8XAJ5                   0.038549           0.009070
# Q8XAL6                   0.039604           0.006601
# Q8XC86                   0.028846           0.006410

# %%
ehec_iupred_agg[ehec_iupred_agg['disorder_category']=='PDR']
# Out:
#            protein_ac          dataset disorder_predictor  disorder_fraction  \
# protein_ac
# Q7DB50         Q7DB50  uniprot-ECs4590        iupred-long           0.150754
# Q8XAJ5         Q8XAJ5  uniprot-ECs1812        iupred-long           0.201814
# Q8XAL6         Q8XAL6  uniprot-ECs1814        iupred-long           0.273927
# Q8XC86         Q8XC86  uniprot-ECs4554        iupred-long           0.166667
#
#            disorder_category
# protein_ac
# Q7DB50                   PDR
# Q8XAJ5                   PDR
# Q8XAL6                   PDR
# Q8XC86                   PDR

# %%
epec_anchor = aepd.load_single_table('../data/anchor/EPEC_effectors/EPEC_anchor.table')
epec_disopred = aepd.load_single_table('../data/disopred/EPEC_effectors/EPEC_disopred-pb.table')
epec_iupred_agg = aepd.load_multi_tables(path_to_folder='../data/iupred_aggregated_disfrac-class/EPEC_effectors/', regex='*long*.table')

# %%
fig=plt.figure(figsize=(4,4))

ax = fig.add_subplot(111)

sns.scatterplot(x=epec_iupred_agg['disorder_fraction'], 
                y=epec_anchor['anchor_motif_density'], 
                hue=epec_iupred_agg['disorder_category'],
                palette = ['#e47171', '#1f77b4', '#d62728', '#6ba5cd'],
                ax=ax)

#handles, labels = ax.get_legend_handles_labels()
#ax.legend([handles[0], handles[2], handles[4], handles[3], handles[1]], ['Categories', 'IDP', 'PDR', 'NDP', 'ORD'])
plt.xlim(-0.01,1)
plt.ylim(-0.01,1)
plt.title('EPEC: Anchor motif density vs disorder fraction');

plt.savefig('../figures/EPEC_anchor_motif_density-vs-iupred-long_disfrac_by_category.png',
            dpi=300)

# %%
fig=plt.figure(figsize=(4,4))

ax = fig.add_subplot(111)

sns.scatterplot(x=epec_iupred_agg['disorder_fraction'], 
                y=epec_anchor['overall_motif_density'], 
                hue=epec_iupred_agg['disorder_category'],
                palette = ['#e47171', '#1f77b4', '#d62728', '#6ba5cd'],
                ax=ax)

#handles, labels = ax.get_legend_handles_labels()
#ax.legend([handles[0], handles[2], handles[4], handles[3], handles[1]], ['Categories', 'IDP', 'PDR', 'NDP', 'ORD'])
plt.xlim(-0.01, 1)
plt.ylim(-0.01, 0.5)
plt.title('EPEC: Overall motif density vs disorder fraction');

plt.savefig('../figures/EPEC_overall_motif_density-vs-iupred-long_disfrac_by_category.png',
            dpi=300)

# %%
epec_iupred_agg[epec_iupred_agg['disorder_category']=='PDR']
# Out:
#             protein_ac     dataset disorder_predictor  disorder_fraction  \
# protein_ac
# A0A0K4TFC7  A0A0K4TFC7  A0A0K4TFC7        iupred-long           0.170648
# B7ULW4          B7ULW4      B7ULW4        iupred-long           0.150171
# B7UMC8          B7UMC8      B7UMC8        iupred-long           0.170854
# B7UR60          B7UR60      B7UR60        iupred-long           0.240909
# Q05129          Q05129      Q05129        iupred-long           0.271028
#
#            disorder_category
# protein_ac
# A0A0K4TFC7               PDR
# B7ULW4                   PDR
# B7UMC8                   PDR
# B7UR60                   PDR
# Q05129                   PDR

# %%
epec_anchor[epec_iupred_agg['disorder_category']=='IDP']
# Out:
#            dataset  anchor_ratio  anchor_motif_occ  anchor_motif_density  \
# protein_ac
# B7UM88        EPEC      0.490291                14              0.653465
# B7UM99        EPEC      0.478182                36              0.498099
#
#             overall_motif_density  motif_occ_density
# protein_ac
# B7UM88                   0.320388           0.067961
# B7UM99                   0.238182           0.065455

# %%
cr_anchor = aepd.load_single_table('../data/anchor/CR_effectors/CR_anchor.table')
cr_disopred = aepd.load_single_table('../data/disopred/CR_effectors/CR_disopred-pb.table')
cr_iupred_agg = aepd.load_multi_tables(path_to_folder='../data/iupred_aggregated_disfrac-class/CR_effectors/', regex='*long*.table')

# %%
print(len(cr_anchor), len(cr_disopred), len(cr_iupred_agg))
# Out:
# 28 28 28

# %%
import seaborn as sns

fig=plt.figure(figsize=(4,4))

ax = fig.add_subplot(111)

sns.scatterplot(x=cr_iupred_agg['disorder_fraction'], 
                y=cr_anchor['anchor_motif_density'], 
                hue=cr_iupred_agg['disorder_category'],
                palette = ['#1f77b4', '#6ba5cd', '#e47171', '#d62728'],
                ax=ax)

#handles, labels = ax.get_legend_handles_labels()
#ax.legend([handles[0], handles[2], handles[4], handles[3], handles[1]], ['Categories', 'IDP', 'PDR', 'NDP', 'ORD'])
plt.xlim(-0.01,1)
plt.ylim(-0.01,1)
plt.title('CR: Anchor motif density vs disorder fraction');

plt.savefig('../figures/CR_anchor_motif_density-vs-iupred-long_disfrac_by_category.png',
            dpi=300)

# %%
import seaborn as sns

fig=plt.figure(figsize=(4,4))

ax = fig.add_subplot(111)

sns.scatterplot(x=cr_iupred_agg['disorder_fraction'], 
                y=cr_anchor['overall_motif_density'], 
                hue=cr_iupred_agg['disorder_category'],
                palette = ['#1f77b4', '#6ba5cd', '#e47171', '#d62728'],
                ax=ax)

#handles, labels = ax.get_legend_handles_labels()
#ax.legend([handles[0], handles[2], handles[4], handles[3], handles[1]], ['Categories', 'IDP', 'PDR', 'NDP', 'ORD'])
plt.xlim(-0.01, 1)
plt.ylim(-0.01, 0.5)
plt.title('CR: Motif density vs disorder fraction');

plt.savefig('../figures/CR_overall_motif_density-vs-iupred-long_disfrac_by_category.png',
            dpi=300)

# %%
cr_iupred_agg[cr_iupred_agg['disorder_category']=='IDP']
# Out:
#            protein_ac dataset disorder_predictor  disorder_fraction  \
# protein_ac
# D2TKD7         D2TKD7  D2TKD7        iupred-long           0.787375
# D2TKE8         D2TKE8  D2TKE8        iupred-long           0.723949
#
#            disorder_category
# protein_ac
# D2TKD7                   IDP
# D2TKE8                   IDP

# %%
cr_anchor[cr_iupred_agg['disorder_category']=='PDR']
# Out:
#            dataset  anchor_ratio  anchor_motif_occ  anchor_motif_density  \
# protein_ac
# D2TJZ4          CR      0.074419                 5               0.40625
# D2TKE1          CR      0.109034                 4               0.40000
#
#             overall_motif_density  motif_occ_density
# protein_ac
# D2TJZ4                   0.030233           0.011628
# D2TKE1                   0.043614           0.012461
