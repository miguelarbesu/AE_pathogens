# %% [markdown]
# # Plotting motif densities vs Disopred disorder fraction by category
#
# Aggregated Disopred scores and derived structural categories are used.
#
# Both Anchor and overall motif densities are plotted.

# %%
import json
import glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import sys
sys.path.append('../src/')

import aepathdisorder as aepd

# %matplotlib inline

# %%
ehec_anchor = aepd.load_single_table('../data/anchor/EHEC_effectors/EHEC_anchor.table')
ehec_disopred = aepd.load_single_table('../data/disopred/EHEC_effectors/EHEC_disopred-pb.table')
ehec_disopred_agg = aepd.load_multi_tables(path_to_folder='../data/disopred_aggregated_disfrac-class/EHEC_effectors/')

# %%
fig=plt.figure(figsize=(4,4))

ax = fig.add_subplot(111)

sns.scatterplot(x=ehec_disopred_agg['disorder_fraction'], 
                y=ehec_anchor['anchor_motif_density'], 
                hue=ehec_disopred_agg['disorder_category'],
                palette = ['#1f77b4', '#6ba5cd', '#d62728', '#e47171'],
                ax=ax)
#handles, labels = ax.get_legend_handles_labels()
#ax.legend([handles[0], handles[2], handles[4], handles[3], handles[1]], ['Categories', 'IDP', 'PDR', 'NDP', 'ORD'])
plt.xlim(-0.01,1)
plt.ylim(-0.01,1)
plt.title('EHEC: Anchor motif density vs disorder fraction');

plt.savefig('../figures/EHEC_motif_density-vs-disopred-disfrac_by_category.png',
            dpi=300)

# %%
fig=plt.figure(figsize=(4,4))

ax = fig.add_subplot(111)

sns.scatterplot(x=ehec_disopred_agg['disorder_fraction'], 
                y=ehec_anchor['overall_motif_density'], 
                hue=ehec_disopred_agg['disorder_category'],
                palette = ['#1f77b4', '#6ba5cd', '#d62728', '#e47171'],
                ax=ax)

#handles, labels = ax.get_legend_handles_labels()
#ax.legend([handles[0], handles[2], handles[4], handles[3], handles[1]], ['Categories', 'IDP', 'PDR', 'NDP', 'ORD'])
plt.xlim(-0.01,1)
plt.ylim(-0.01,0.5)
plt.title('EHEC: Overall motif density vs disorder fraction');

plt.savefig('../figures/EHEC_overall_motif_density-vs-disopred-disfrac_by_category.png',
            dpi=300)

# %%
ehec_anchor[ehec_disopred_agg['disorder_category']=='IDP']
# Out:
#            dataset  anchor_ratio  anchor_motif_occ  anchor_motif_density  \
# protein_ac
# P0DJ88        EHEC      0.620178                21              0.511962
# Q7DB77        EHEC      0.530466                60              0.601351
# Q7DB85        EHEC      0.588710                20              0.705479
#
#             overall_motif_density  motif_occ_density
# protein_ac
# P0DJ88                   0.317507           0.062315
# Q7DB77                   0.318996           0.107527
# Q7DB85                   0.415323           0.080645

# %%
ehec_disopred_agg[ehec_disopred_agg['disorder_category']=='IDP']
# Out:
#            protein_ac         dataset disorder_predictor  disorder_fraction  \
# protein_ac
# P0DJ88         P0DJ88  EHEC_effectors         disopred31           0.424332
# Q7DB77         Q7DB77  EHEC_effectors         disopred31           0.331541
# Q7DB85         Q7DB85  EHEC_effectors         disopred31           0.600806
#
#            disorder_category
# protein_ac
# P0DJ88                   IDP
# Q7DB77                   IDP
# Q7DB85                   IDP

# %%
epec_anchor = aepd.load_single_table('../data/anchor/EPEC_effectors/EPEC_anchor.table')
epec_disopred = aepd.load_single_table('../data/disopred/EPEC_effectors/EPEC_disopred-pb.table')
epec_disopred_agg = aepd.load_multi_tables(path_to_folder='../data/disopred_aggregated_disfrac-class/EPEC_effectors/')

# %%
fig=plt.figure(figsize=(4,4))

ax = fig.add_subplot(111)

sns.scatterplot(x=epec_disopred_agg['disorder_fraction'], 
                y=epec_anchor['anchor_motif_density'], 
                hue=epec_disopred_agg['disorder_category'],
                palette = ['#1f77b4', '#6ba5cd','#e47171', '#d62728'],
                ax=ax)

#handles, labels = ax.get_legend_handles_labels()
#ax.legend([handles[0], handles[2], handles[4], handles[3], handles[1]], ['Categories', 'IDP', 'PDR', 'NDP', 'ORD'])
plt.xlim(-0.01,1)
plt.ylim(-0.01,1)
plt.title('EPEC: Anchor motif density vs disorder fraction');

plt.savefig('../figures/EPEC_anchor_motif_density-vs-disopred-disfrac_by_category.png',
            dpi=300)

# %%
fig=plt.figure(figsize=(4,4))

ax = fig.add_subplot(111)

sns.scatterplot(x=epec_disopred_agg['disorder_fraction'], 
                y=epec_anchor['overall_motif_density'], 
                hue=epec_disopred_agg['disorder_category'],
                palette = ['#1f77b4', '#6ba5cd','#e47171', '#d62728'],
                ax=ax)

#handles, labels = ax.get_legend_handles_labels()
#ax.legend([handles[0], handles[2], handles[4], handles[3], handles[1]], ['Categories', 'IDP', 'PDR', 'NDP', 'ORD'])
plt.xlim(-0.01, 1)
plt.ylim(-0.01, 0.5)
plt.title('EPEC: Overall motif density vs disorder fraction');

plt.savefig('../figures/EPEC_overall_motif_density-vs-disopred-disfrac_by_category.png',
            dpi=300)

# %%
epec_disopred_agg[epec_disopred_agg['disorder_category']=='IDP']
# Out:
#            protein_ac         dataset disorder_predictor  disorder_fraction  \
# protein_ac
# B7UM88         B7UM88  EPEC_effectors         disopred31           0.592233
# B7UM99         B7UM99  EPEC_effectors         disopred31           0.400000
#
#            disorder_category
# protein_ac
# B7UM88                   IDP
# B7UM99                   IDP

# %%
epec_anchor[epec_disopred_agg['disorder_category']=='IDP']
# Out:
#            dataset  anchor_ratio  anchor_motif_occ  anchor_motif_density  \
# protein_ac
# B7UM88        EPEC      0.490291                14              0.653465
# B7UM99        EPEC      0.478182                36              0.498099
#
#             overall_motif_density  motif_occ_density
# protein_ac
# B7UM88                   0.320388           0.067961
# B7UM99                   0.238182           0.065455

# %%
cr_anchor = aepd.load_single_table('../data/anchor/CR_effectors/CR_anchor.table')
cr_disopred = aepd.load_single_table('../data/disopred/CR_effectors/CR_disopred-pb.table')
cr_disopred_agg = aepd.load_multi_tables(path_to_folder='../data/disopred_aggregated_disfrac-class/CR_effectors/')

# %%
print(len(cr_anchor), len(cr_disopred), len(cr_disopred_agg))
# Out:
# 28 28 28

# %%
import seaborn as sns

fig=plt.figure(figsize=(4,4))

ax = fig.add_subplot(111)

sns.scatterplot(x=cr_disopred_agg['disorder_fraction'], 
                y=cr_anchor['anchor_motif_density'], 
                hue=cr_disopred_agg['disorder_category'],
                palette = ['#1f77b4', '#6ba5cd','#d62728', '#e47171'],
                ax=ax)

#handles, labels = ax.get_legend_handles_labels()
#ax.legend([handles[0], handles[2], handles[4], handles[3], handles[1]], ['Categories', 'IDP', 'PDR', 'NDP', 'ORD'])
plt.xlim(-0.01,1)
plt.ylim(-0.01,1)
plt.title('CR: Anchor motif density vs disorder fraction');

plt.savefig('../figures/CR_anchor_motif_density-vs-disopred-disfrac_by_category.png',
            dpi=300)

# %%
import seaborn as sns

fig=plt.figure(figsize=(4,4))

ax = fig.add_subplot(111)

sns.scatterplot(x=cr_disopred_agg['disorder_fraction'], 
                y=cr_anchor['overall_motif_density'], 
                hue=cr_disopred_agg['disorder_category'],
                palette = ['#1f77b4', '#6ba5cd','#d62728', '#e47171'],
                ax=ax)

#handles, labels = ax.get_legend_handles_labels()
#ax.legend([handles[0], handles[2], handles[4], handles[3], handles[1]], ['Categories', 'IDP', 'PDR', 'NDP', 'ORD'])
plt.xlim(-0.01, 1)
plt.ylim(-0.01, 0.5)
plt.title('CR: Motif density vs disorder fraction');

plt.savefig('../figures/CR_overall_motif_density-vs-disopred-disfrac_by_category.png',
            dpi=300)

# %%
cr_disopred_agg[cr_disopred_agg['disorder_category']=='IDP']
# Out:
#            protein_ac       dataset disorder_predictor  disorder_fraction  \
# protein_ac
# D2TKD7         D2TKD7  CR_effectors         disopred31           0.877076
# D2TKE8         D2TKE8  CR_effectors         disopred31           0.469835
#
#            disorder_category
# protein_ac
# D2TKD7                   IDP
# D2TKE8                   IDP

# %%
cr_anchor[cr_disopred_agg['disorder_category']=='IDP']
# Out:
#            dataset  anchor_ratio  anchor_motif_occ  anchor_motif_density  \
# protein_ac
# D2TKD7          CR      0.581395                29              0.685714
# D2TKE8          CR      0.497258                46              0.503676
#
#             overall_motif_density  motif_occ_density
# protein_ac
# D2TKD7                   0.398671           0.096346
# D2TKE8                   0.250457           0.084095
